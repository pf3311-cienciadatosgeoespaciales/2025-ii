# %% [markdown]
# # pandas: paquete para análisis y manipulación de datos

# %% [markdown]
# ## Descripción general

# %% [markdown]
# [pandas](https://pandas.pydata.org/) es una biblioteca de Python para análisis y manipulación de datos. Proporciona estructuras de datos y operaciones para manejar tablas numéricas y series temporales. Fue creada por Wes McKinney in 2008. El nombre "pandas" hace referencia tanto a "*Panel Data*" como a "*Python Data Analysis*".
#
# Como su estructura principal, pandas implementa el `DataFrame`, el cual es un arreglo rectangular de datos, organizado en filas y columnas.

# %% [markdown]
# ## Carga

# %%
# Se acostumbra cargar pandas con el alias pd

import pandas as pd

# %% [markdown]
# ## Estructuras de datos
# Las dos principales estructuras de datos de pandas son `Series` y `DataFrames`.

# %% [markdown]
# ### Series
# Las [Series](https://pandas.pydata.org/docs/reference/api/pandas.Series.html?highlight=series#pandas.Series) son arreglos unidimensionales que contienen datos de cualquier tipo. Se asemejan a una columna de una tabla.

# %%
# Definición de una serie

primos = [2, 3, 5, 7, 11]
serie_primos = pd.Series(primos)

serie_primos
# Out:
# 0     2
# 1     3
# 2     5
# 3     7
# 4    11
# dtype: int64

# %% [markdown]
# Cada elemento de una serie tiene un índice (i.e. posición), comenzando con 0.

# %%
# Primer elemento
print("Primer elemento:", serie_primos[0])

# Segundo elemento
print("Segundo elemento:", serie_primos[1])
# Out:
# Primer elemento: 2
# Segundo elemento: 3

# %% [markdown]
# Los índices también pueden tener etiquetas personalizadas.

# %%
# Índice de una serie con etiquetas personalizadas

serie_primos = pd.Series(primos, index = ["A", "B", "C", "D", "E"])

serie_primos
# Out:
# A     2
# B     3
# C     5
# D     7
# E    11
# dtype: int64

# %%
# Elemento en el índice "D"
print(serie_primos["D"])
# Out:
# 7

# %% [markdown]
# ### DataFrames
# Los [DataFrames](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame) son estructuras multidimensionales. Una serie puede verse como una columna de una tabla y un dataframe como una tabla completa. Un dataframe puede construirse a partir de varias series.

# %%
# Dataframe construído a partir de dos series

datos = {
  "pais": ["PA", "CR", "NI"],
  "poblacion": [4.1, 5.0, 6.6]
}

paises = pd.DataFrame(datos)

paises
# Out:
#   pais  poblacion
# 0   PA        4.1
# 1   CR        5.0
# 2   NI        6.6

# %% [markdown]
# El operador **loc** permite retornar una o más filas de un dataframe, de acuerdo con un índice o con un vector de índices.

# %%
# Segundo elemento
paises.loc[1]
# Out:
# pais          CR
# poblacion    5.0
# Name: 1, dtype: object

# %%
# Segundo y tercer elemento
paises.loc[[1, 2]]
# Out:
#   pais  poblacion
# 1   CR        5.0
# 2   NI        6.6

# %% [markdown]
# Los índices de los dataframes también pueden etiquetarse:

# %%
paises = pd.DataFrame(datos, index=["pais0", "pais1", "pais2"])
paises
# Out:
#       pais  poblacion
# pais0   PA        4.1
# pais1   CR        5.0
# pais2   NI        6.6

# %%
# Elemento en "pais0"
paises.loc["pais0"]
# Out:
# pais          PA
# poblacion    4.1
# Name: pais0, dtype: object

# %% [markdown]
# ## Operaciones básicas

# %% [markdown]
# Seguidamente, se describen y ejemplifican algunas de las funciones básicas de pandas.
#
# En los siguientes ejemplos, se utilizará un conjunto de registros de presencia de felinos (familia *Felidae*) de Costa Rica, obtenido a través de una [consulta al portal de GBIF](https://www.gbif.org/occurrence/download/0016217-210914110416597).

# %% [markdown]
# ### read_csv() - carga de datos

# %%
felinos = pd.read_csv("https://raw.githubusercontent.com/pf3311-cienciadatosgeoespaciales/2021-iii/main/contenido/b/datos/felinos.csv", sep="\t")

# %% [markdown]
# ### info() - información general sobre un conjunto de datos

# %%
felinos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   gbifID                            150 non-null    int64
#  1   datasetKey                        150 non-null    object
#  2   occurrenceID                      147 non-null    object
#  3   kingdom                           150 non-null    object
#  4   phylum                            150 non-null    object
#  5   class                             150 non-null    object
#  6   order                             150 non-null    object
#  7   family                            150 non-null    object
#  8   genus                             150 non-null    object
#  9   species                           150 non-null    object
#  10  infraspecificEpithet              18 non-null     object
#  11  taxonRank                         150 non-null    object
#  12  scientificName                    150 non-null    object
#  13  verbatimScientificName            150 non-null    object
#  14  verbatimScientificNameAuthorship  16 non-null     object
#  15  countryCode                       150 non-null    object
#  16  locality                          41 non-null     object
#  17  stateProvince                     132 non-null    object
#  18  occurrenceStatus                  150 non-null    object
#  19  individualCount                   27 non-null     float64
#  20  publishingOrgKey                  150 non-null    object
#  21  decimalLatitude                   150 non-null    float64
#  22  decimalLongitude                  150 non-null    float64
#  23  coordinateUncertaintyInMeters     129 non-null    float64
#  24  coordinatePrecision               0 non-null      float64
#  25  elevation                         3 non-null      float64
#  26  elevationAccuracy                 3 non-null      float64
#  27  depth                             3 non-null      float64
#  28  depthAccuracy                     3 non-null      float64
#  29  eventDate                         148 non-null    object
#  30  day                               147 non-null    float64
#  31  month                             148 non-null    float64
#  32  year                              148 non-null    float64
#  33  taxonKey                          150 non-null    int64
#  34  speciesKey                        150 non-null    int64
#  35  basisOfRecord                     150 non-null    object
#  36  institutionCode                   137 non-null    object
#  37  collectionCode                    150 non-null    object
#  38  catalogNumber                     150 non-null    object
#  39  recordNumber                      4 non-null      object
#  40  identifiedBy                      121 non-null    object
#  41  dateIdentified                    109 non-null    object
#  42  license                           150 non-null    object
#  43  rightsHolder                      132 non-null    object
#  44  recordedBy                        135 non-null    object
#  45  typeStatus                        0 non-null      float64
#  46  establishmentMeans                10 non-null     object
#  47  lastInterpreted                   150 non-null    object
#  48  mediaType                         102 non-null    object
#  49  issue                             137 non-null    object
# dtypes: float64(13), int64(3), object(34)
# memory usage: 58.7+ KB

# %% [markdown]
# ### head(), tail(), sample() - despliegue de filas de un conjunto de datos

# %%
# Primeros 10 registros
felinos.head()
# Out:
#        gbifID                            datasetKey  \
# 0  3337559907  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  3333401669  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  3325502794  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  3314547422  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  3307298689  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                         occurrenceID   kingdom    phylum  \
# 0  https://www.inaturalist.org/observations/90794984  Animalia  Chordata
# 1  https://www.inaturalist.org/observations/88270427  Animalia  Chordata
# 2  https://www.inaturalist.org/observations/85490861  Animalia  Chordata
# 3  https://www.inaturalist.org/observations/84224884  Animalia  Chordata
# 4  https://www.inaturalist.org/observations/82810053  Animalia  Chordata
#
#       class      order   family      genus             species  ...  \
# 0  Mammalia  Carnivora  Felidae       Puma       Puma concolor  ...
# 1  Mammalia  Carnivora  Felidae       Puma       Puma concolor  ...
# 2  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 3  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 4  Mammalia  Carnivora  Felidae  Leopardus    Leopardus wiedii  ...
#
#                  identifiedBy       dateIdentified       license  \
# 0             Marvin López M.  2021-08-11T17:02:57  CC_BY_NC_4_0
# 1  Tiziano Luka Pesci Rubilar  2021-07-23T17:52:04  CC_BY_NC_4_0
# 2      Sofía Pastor Parajeles  2021-07-03T16:59:46  CC_BY_NC_4_0
# 3      Sofía Pastor Parajeles  2021-06-23T20:39:47  CC_BY_NC_4_0
# 4                       David  2021-06-13T09:10:50  CC_BY_NC_4_0
#
#              rightsHolder              recordedBy typeStatus  \
# 0         Marvin López M.         Marvin López M.        NaN
# 1           Rebeca Quirós           Rebeca Quirós        NaN
# 2  Sofía Pastor Parajeles  Sofía Pastor Parajeles        NaN
# 3  Sofía Pastor Parajeles  Sofía Pastor Parajeles        NaN
# 4                   David                   David        NaN
#
#   establishmentMeans           lastInterpreted   mediaType               issue
# 0                NaN  2021-09-23T21:26:16.096Z  StillImage  COORDINATE_ROUNDED
# 1                NaN  2021-09-23T21:15:51.507Z         NaN  COORDINATE_ROUNDED
# 2                NaN  2021-09-23T20:59:21.345Z  StillImage  COORDINATE_ROUNDED
# 3                NaN  2021-09-23T21:25:26.648Z  StillImage                 NaN
# 4                NaN  2021-09-23T21:25:57.478Z  StillImage  COORDINATE_ROUNDED
#
# [5 rows x 50 columns]

# %%
# Últimos 15 registros
felinos.tail()
# Out:
#         gbifID                            datasetKey  \
# 145  439779436  7e2989f0-f762-11e1-a439-00145eb45e9a
# 146   45869665  847e2306-f762-11e1-a439-00145eb45e9a
# 147   45869664  847e2306-f762-11e1-a439-00145eb45e9a
# 148   45869301  847e2306-f762-11e1-a439-00145eb45e9a
# 149   45869265  847e2306-f762-11e1-a439-00145eb45e9a
#
#                         occurrenceID   kingdom    phylum     class      order  \
# 145                              NaN  Animalia  Chordata  Mammalia  Carnivora
# 146  urn:catalog:LSUMZ:Mammals:13378  Animalia  Chordata  Mammalia  Carnivora
# 147  urn:catalog:LSUMZ:Mammals:13377  Animalia  Chordata  Mammalia  Carnivora
# 148  urn:catalog:LSUMZ:Mammals:10219  Animalia  Chordata  Mammalia  Carnivora
# 149   urn:catalog:LSUMZ:Mammals:9289  Animalia  Chordata  Mammalia  Carnivora
#
#       family      genus             species  ... identifiedBy dateIdentified  \
# 145  Felidae       Puma       Puma concolor  ...          NaN            NaN
# 146  Felidae  Leopardus  Leopardus tigrinus  ...          NaN            NaN
# 147  Felidae  Leopardus  Leopardus tigrinus  ...          NaN            NaN
# 148  Felidae  Leopardus  Leopardus pardalis  ...          NaN            NaN
# 149  Felidae  Leopardus  Leopardus pardalis  ...          NaN            NaN
#
#        license rightsHolder          recordedBy typeStatus establishmentMeans  \
# 145  CC_BY_4_0          NaN                 NaN        NaN                NaN
# 146    CC0_1_0          NaN  Gardner, Alfred L.        NaN             NATIVE
# 147    CC0_1_0          NaN  Gardner, Alfred L.        NaN             NATIVE
# 148    CC0_1_0          NaN    Arnold, Keith A.        NaN             NATIVE
# 149    CC0_1_0          NaN                 NaN        NaN             NATIVE
#
#               lastInterpreted   mediaType  \
# 145  2021-09-24T03:32:37.674Z  StillImage
# 146  2021-09-24T06:03:59.587Z         NaN
# 147  2021-09-24T06:03:59.587Z         NaN
# 148  2021-09-24T06:03:59.952Z         NaN
# 149  2021-09-24T06:03:59.933Z         NaN
#
#                                                  issue
# 145  GEODETIC_DATUM_ASSUMED_WGS84;RECORDED_DATE_INV...
# 146                    INSTITUTION_COLLECTION_MISMATCH
# 147                    INSTITUTION_COLLECTION_MISMATCH
# 148                    INSTITUTION_COLLECTION_MISMATCH
# 149                    INSTITUTION_COLLECTION_MISMATCH
#
# [5 rows x 50 columns]

# %%
# 5 registros seleccionados aleatoriamente
felinos.sample(5)
# Out:
#          gbifID                            datasetKey  \
# 133   891041333  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 120  1563873476  4bfac3ea-8763-4f4b-a71a-76a6f5f243d3
# 111  1913186276  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 122  1305160376  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 112  1880666129  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                           occurrenceID   kingdom    phylum  \
# 133     http://www.inaturalist.org/observations/519142  Animalia  Chordata
# 120                                      MCZ:Cryo:3120  Animalia  Chordata
# 111  https://www.inaturalist.org/observations/16423519  Animalia  Chordata
# 122    http://www.inaturalist.org/observations/3958138  Animalia  Chordata
# 112  http://conabio.inaturalist.org/observations/48...  Animalia  Chordata
#
#         class      order   family      genus             species  ...  \
# 133  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 120  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 111  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 122  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 112  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
#
#               identifiedBy       dateIdentified       license  \
# 133              canopalma  2014-02-03T15:52:21  CC_BY_NC_4_0
# 120  Judith Marie Chupasko                  NaN  CC_BY_NC_4_0
# 111    The Jaguar's Jungle  2018-09-11T17:52:42  CC_BY_NC_4_0
# 122             Matt Brady  2016-08-25T04:00:05     CC_BY_4_0
# 112          Richard Joyce  2017-04-24T02:28:48  CC_BY_NC_4_0
#
#                                  rightsHolder             recordedBy  \
# 133                                 canopalma              canopalma
# 120  President and Fellows of Harvard College  Judith Marie Chupasko
# 111                       The Jaguar's Jungle    The Jaguar's Jungle
# 122                                Matt Brady             Matt Brady
# 112                                mirnasalas             mirnasalas
#
#     typeStatus establishmentMeans           lastInterpreted   mediaType  \
# 133        NaN                NaN  2021-09-23T21:21:23.561Z  StillImage
# 120        NaN                NaN  2021-10-01T01:53:10.737Z         NaN
# 111        NaN                NaN  2021-09-23T21:19:23.360Z  StillImage
# 122        NaN                NaN  2021-09-23T21:17:45.433Z         NaN
# 112        NaN                NaN  2021-09-23T21:16:17.403Z  StillImage
#
#                                                  issue
# 133                                                NaN
# 120  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 111                                 COORDINATE_ROUNDED
# 122                                                NaN
# 112                                 COORDINATE_ROUNDED
#
# [5 rows x 50 columns]

# %% [markdown]
# Los contenidos de un data frame también pueden desplegarse al escribir su nombre en la consola de Python.

# %%
felinos
# Out:
#          gbifID                            datasetKey  \
# 0    3337559907  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1    3333401669  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2    3325502794  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3    3314547422  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4    3307298689  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# ..          ...                                   ...
# 145   439779436  7e2989f0-f762-11e1-a439-00145eb45e9a
# 146    45869665  847e2306-f762-11e1-a439-00145eb45e9a
# 147    45869664  847e2306-f762-11e1-a439-00145eb45e9a
# 148    45869301  847e2306-f762-11e1-a439-00145eb45e9a
# 149    45869265  847e2306-f762-11e1-a439-00145eb45e9a
#
#                                           occurrenceID   kingdom    phylum  \
# 0    https://www.inaturalist.org/observations/90794984  Animalia  Chordata
# 1    https://www.inaturalist.org/observations/88270427  Animalia  Chordata
# 2    https://www.inaturalist.org/observations/85490861  Animalia  Chordata
# 3    https://www.inaturalist.org/observations/84224884  Animalia  Chordata
# 4    https://www.inaturalist.org/observations/82810053  Animalia  Chordata
# ..                                                 ...       ...       ...
# 145                                                NaN  Animalia  Chordata
# 146                    urn:catalog:LSUMZ:Mammals:13378  Animalia  Chordata
# 147                    urn:catalog:LSUMZ:Mammals:13377  Animalia  Chordata
# 148                    urn:catalog:LSUMZ:Mammals:10219  Animalia  Chordata
# 149                     urn:catalog:LSUMZ:Mammals:9289  Animalia  Chordata
#
#         class      order   family      genus             species  ...  \
# 0    Mammalia  Carnivora  Felidae       Puma       Puma concolor  ...
# 1    Mammalia  Carnivora  Felidae       Puma       Puma concolor  ...
# 2    Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 3    Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 4    Mammalia  Carnivora  Felidae  Leopardus    Leopardus wiedii  ...
# ..        ...        ...      ...        ...                 ...  ...
# 145  Mammalia  Carnivora  Felidae       Puma       Puma concolor  ...
# 146  Mammalia  Carnivora  Felidae  Leopardus  Leopardus tigrinus  ...
# 147  Mammalia  Carnivora  Felidae  Leopardus  Leopardus tigrinus  ...
# 148  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
# 149  Mammalia  Carnivora  Felidae  Leopardus  Leopardus pardalis  ...
#
#                    identifiedBy       dateIdentified       license  \
# 0               Marvin López M.  2021-08-11T17:02:57  CC_BY_NC_4_0
# 1    Tiziano Luka Pesci Rubilar  2021-07-23T17:52:04  CC_BY_NC_4_0
# 2        Sofía Pastor Parajeles  2021-07-03T16:59:46  CC_BY_NC_4_0
# 3        Sofía Pastor Parajeles  2021-06-23T20:39:47  CC_BY_NC_4_0
# 4                         David  2021-06-13T09:10:50  CC_BY_NC_4_0
# ..                          ...                  ...           ...
# 145                         NaN                  NaN     CC_BY_4_0
# 146                         NaN                  NaN       CC0_1_0
# 147                         NaN                  NaN       CC0_1_0
# 148                         NaN                  NaN       CC0_1_0
# 149                         NaN                  NaN       CC0_1_0
#
#                rightsHolder              recordedBy typeStatus  \
# 0           Marvin López M.         Marvin López M.        NaN
# 1             Rebeca Quirós           Rebeca Quirós        NaN
# 2    Sofía Pastor Parajeles  Sofía Pastor Parajeles        NaN
# 3    Sofía Pastor Parajeles  Sofía Pastor Parajeles        NaN
# 4                     David                   David        NaN
# ..                      ...                     ...        ...
# 145                     NaN                     NaN        NaN
# 146                     NaN      Gardner, Alfred L.        NaN
# 147                     NaN      Gardner, Alfred L.        NaN
# 148                     NaN        Arnold, Keith A.        NaN
# 149                     NaN                     NaN        NaN
#
#     establishmentMeans           lastInterpreted   mediaType  \
# 0                  NaN  2021-09-23T21:26:16.096Z  StillImage
# 1                  NaN  2021-09-23T21:15:51.507Z         NaN
# 2                  NaN  2021-09-23T20:59:21.345Z  StillImage
# 3                  NaN  2021-09-23T21:25:26.648Z  StillImage
# 4                  NaN  2021-09-23T21:25:57.478Z  StillImage
# ..                 ...                       ...         ...
# 145                NaN  2021-09-24T03:32:37.674Z  StillImage
# 146             NATIVE  2021-09-24T06:03:59.587Z         NaN
# 147             NATIVE  2021-09-24T06:03:59.587Z         NaN
# 148             NATIVE  2021-09-24T06:03:59.952Z         NaN
# 149             NATIVE  2021-09-24T06:03:59.933Z         NaN
#
#                                                  issue
# 0                                   COORDINATE_ROUNDED
# 1                                   COORDINATE_ROUNDED
# 2                                   COORDINATE_ROUNDED
# 3                                                  NaN
# 4                                   COORDINATE_ROUNDED
# ..                                                 ...
# 145  GEODETIC_DATUM_ASSUMED_WGS84;RECORDED_DATE_INV...
# 146                    INSTITUTION_COLLECTION_MISMATCH
# 147                    INSTITUTION_COLLECTION_MISMATCH
# 148                    INSTITUTION_COLLECTION_MISMATCH
# 149                    INSTITUTION_COLLECTION_MISMATCH
#
# [150 rows x 50 columns]

# %% [markdown]
# ### Selección de columnas

# %% [markdown]
# Las columnas que se despliegan en un data frame pueden especificarse mediante una lista.

# %%
# Despliegue de las columnas con el nombre científico, la especie, la fecha, el año, el mes y el día

felinos[["scientificName", "species", "eventDate", "year", "month", "day"]]
# Out:
#                           scientificName             species  \
# 0         Puma concolor (Linnaeus, 1771)       Puma concolor
# 1         Puma concolor (Linnaeus, 1771)       Puma concolor
# 2    Leopardus pardalis (Linnaeus, 1758)  Leopardus pardalis
# 3    Leopardus pardalis (Linnaeus, 1758)  Leopardus pardalis
# 4        Leopardus wiedii (Schinz, 1821)    Leopardus wiedii
# ..                                   ...                 ...
# 145       Puma concolor (Linnaeus, 1771)       Puma concolor
# 146  Leopardus tigrinus (Schreber, 1775)  Leopardus tigrinus
# 147  Leopardus tigrinus (Schreber, 1775)  Leopardus tigrinus
# 148  Leopardus pardalis (Linnaeus, 1758)  Leopardus pardalis
# 149  Leopardus pardalis (Linnaeus, 1758)  Leopardus pardalis
#
#                eventDate    year  month   day
# 0    2021-08-11T10:22:36  2021.0    8.0  11.0
# 1    2021-07-15T16:22:29  2021.0    7.0  15.0
# 2    2021-07-01T19:28:25  2021.0    7.0   1.0
# 3    2021-06-23T10:55:00  2021.0    6.0  23.0
# 4    2015-12-05T14:41:42  2015.0   12.0   5.0
# ..                   ...     ...    ...   ...
# 145                  NaN     NaN    NaN   NaN
# 146  1967-05-15T00:00:00  1967.0    5.0  15.0
# 147  1967-02-01T00:00:00  1967.0    2.0   1.0
# 148  1965-06-28T00:00:00  1965.0    6.0  28.0
# 149  1963-02-03T00:00:00  1963.0    2.0   3.0
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Selección de filas

# %%
# Selección de filas correspondientes a jaguares (*Panthera onca*)
jaguares = felinos[felinos["species"] == "Panthera onca"]

# Despliegue de los primeros registros
jaguares.head()
# Out:
#         gbifID                            datasetKey  \
# 21  3008449314  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 32  2860189171  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 38  2850700339  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 57  2802770349  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 61  2629043484  09d2da7b-4699-4e45-b0da-73c982660c98
#
#                                          occurrenceID   kingdom    phylum  \
# 21  https://www.inaturalist.org/observations/15270189  Animalia  Chordata
# 32  https://www.inaturalist.org/observations/58257138  Animalia  Chordata
# 38  https://www.inaturalist.org/observations/55493722  Animalia  Chordata
# 57  https://www.inaturalist.org/observations/15255648  Animalia  Chordata
# 61  urn:catalog:KU:KUM:145971:08353198cc55c65471bf...  Animalia  Chordata
#
#        class      order   family     genus        species  ...  \
# 21  Mammalia  Carnivora  Felidae  Panthera  Panthera onca  ...
# 32  Mammalia  Carnivora  Felidae  Panthera  Panthera onca  ...
# 38  Mammalia  Carnivora  Felidae  Panthera  Panthera onca  ...
# 57  Mammalia  Carnivora  Felidae  Panthera  Panthera onca  ...
# 61  Mammalia  Carnivora  Felidae  Panthera  Panthera onca  ...
#
#                         identifiedBy       dateIdentified       license  \
# 21                         mike_cove  2018-08-09T20:10:35       CC0_1_0
# 32               Kate Rothra Fleming  2020-09-01T16:56:35  CC_BY_NC_4_0
# 38                  Osa Conservation  2020-08-05T14:47:40  CC_BY_NC_4_0
# 57                     James Telford  2018-08-09T07:22:08     CC_BY_4_0
# 61  Consuelo Lorenzo & Jorge Bolaños                  NaN     CC_BY_4_0
#
#                                          rightsHolder           recordedBy  \
# 21                                          mike_cove            mike_cove
# 32                                Kate Rothra Fleming  Kate Rothra Fleming
# 38                                   Osa Conservation     Osa Conservation
# 57                                      James Telford        James Telford
# 61  Comisión Nacional para el Conocimiento y Uso d...        NO DISPONIBLE
#
#    typeStatus establishmentMeans           lastInterpreted   mediaType  \
# 21        NaN                NaN  2021-09-23T20:57:45.632Z         NaN
# 32        NaN                NaN  2021-09-23T21:14:12.219Z  StillImage
# 38        NaN                NaN  2021-09-23T21:08:25.102Z  StillImage
# 57        NaN                NaN  2021-09-23T20:58:14.603Z         NaN
# 61        NaN                NaN  2021-09-23T18:42:40.301Z         NaN
#
#                                                 issue
# 21                                 COORDINATE_ROUNDED
# 32                                 COORDINATE_ROUNDED
# 38                                 COORDINATE_ROUNDED
# 57                                 COORDINATE_ROUNDED
# 61  TYPE_STATUS_INVALID;OCCURRENCE_STATUS_INFERRED...
#
# [5 rows x 50 columns]

# %%
# Selección de filas correspondientes a jaguares (*Panthera onca*) o pumas (*Puma concolor*)
jaguares_pumas = felinos[(felinos["species"] == "Panthera onca") | (felinos["species"] == "Puma concolor")]

# Despliegue de los primeros registros
jaguares_pumas.head(10)
# Out:
#         gbifID                            datasetKey  \
# 0   3337559907  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1   3333401669  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 6   3302057398  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 10  3097275563  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 11  3079910798  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 12  3079872785  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 13  3067612232  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 17  3031700803  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 20  3008566753  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 21  3008449314  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                                          occurrenceID   kingdom    phylum  \
# 0   https://www.inaturalist.org/observations/90794984  Animalia  Chordata
# 1   https://www.inaturalist.org/observations/88270427  Animalia  Chordata
# 6   https://www.inaturalist.org/observations/81502744  Animalia  Chordata
# 10  https://www.inaturalist.org/observations/73407648  Animalia  Chordata
# 11  https://www.inaturalist.org/observations/73053113  Animalia  Chordata
# 12  https://www.inaturalist.org/observations/73053107  Animalia  Chordata
# 13  https://www.inaturalist.org/observations/66718421  Animalia  Chordata
# 17  https://www.inaturalist.org/observations/68067200  Animalia  Chordata
# 20  https://www.inaturalist.org/observations/66811638  Animalia  Chordata
# 21  https://www.inaturalist.org/observations/15270189  Animalia  Chordata
#
#        class      order   family     genus        species  ...  \
# 0   Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 1   Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 6   Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 10  Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 11  Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 12  Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 13  Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 17  Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 20  Mammalia  Carnivora  Felidae      Puma  Puma concolor  ...
# 21  Mammalia  Carnivora  Felidae  Panthera  Panthera onca  ...
#
#                     identifiedBy       dateIdentified       license  \
# 0                Marvin López M.  2021-08-11T17:02:57  CC_BY_NC_4_0
# 1     Tiziano Luka Pesci Rubilar  2021-07-23T17:52:04  CC_BY_NC_4_0
# 6       Michelle Monge-Velazquez  2021-06-04T00:10:47  CC_BY_NC_4_0
# 10  Jaime Marcelo Aranda Sánchez  2021-04-09T22:42:23  CC_BY_NC_4_0
# 11                    gernotkunz  2021-04-05T21:48:18  CC_BY_NC_4_0
# 12                    gernotkunz  2021-04-05T21:48:17  CC_BY_NC_4_0
# 13              Jeff Mollenhauer  2020-12-18T01:09:50  CC_BY_NC_4_0
# 17               Marian Paniagua  2021-01-14T20:04:58  CC_BY_NC_4_0
# 20                        jayras  2020-12-20T05:44:17  CC_BY_NC_4_0
# 21                     mike_cove  2018-08-09T20:10:35       CC0_1_0
#
#                 rightsHolder                recordedBy typeStatus  \
# 0            Marvin López M.           Marvin López M.        NaN
# 1              Rebeca Quirós             Rebeca Quirós        NaN
# 6   Michelle Monge-Velazquez  Michelle Monge-Velazquez        NaN
# 10                  nubegris                  nubegris        NaN
# 11                gernotkunz                gernotkunz        NaN
# 12                gernotkunz                gernotkunz        NaN
# 13          Jeff Mollenhauer          Jeff Mollenhauer        NaN
# 17           Marian Paniagua           Marian Paniagua        NaN
# 20           Pacho Gutierrez           Pacho Gutierrez        NaN
# 21                 mike_cove                 mike_cove        NaN
#
#    establishmentMeans           lastInterpreted   mediaType  \
# 0                 NaN  2021-09-23T21:26:16.096Z  StillImage
# 1                 NaN  2021-09-23T21:15:51.507Z         NaN
# 6                 NaN  2021-09-23T21:15:55.933Z  StillImage
# 10                NaN  2021-09-23T21:15:03.814Z  StillImage
# 11                NaN  2021-09-23T21:24:37.211Z         NaN
# 12                NaN  2021-09-23T21:23:35.478Z         NaN
# 13                NaN  2021-09-23T21:09:44.468Z  StillImage
# 17                NaN  2021-09-23T21:14:47.597Z  StillImage
# 20                NaN  2021-09-23T21:14:42.430Z  StillImage
# 21                NaN  2021-09-23T20:57:45.632Z         NaN
#
#                  issue
# 0   COORDINATE_ROUNDED
# 1   COORDINATE_ROUNDED
# 6   COORDINATE_ROUNDED
# 10  COORDINATE_ROUNDED
# 11  COORDINATE_ROUNDED
# 12  COORDINATE_ROUNDED
# 13  COORDINATE_ROUNDED
# 17  COORDINATE_ROUNDED
# 20  COORDINATE_ROUNDED
# 21  COORDINATE_ROUNDED
#
# [10 rows x 50 columns]

# %% [markdown]
# ## Operaciones de análisis

# %% [markdown]
# ### Graficación

# %% [markdown]
# #### Carga de bibliotecas

# %%
import matplotlib.pyplot as plt # biblioteca de graficación
# %matplotlib inline

import calendar # biblioteca para manejo de fechas

# %% [markdown]
# #### Estilo de los gráficos

# %%
# Estilo de los gráficos
plt.style.use('ggplot')

# %% [markdown]
# #### Ejemplos de gráficos

# %% [markdown]
# ##### Distribución de registros de presencia por año

# %%
# Cambio del tipo de datos del campo de fecha
felinos["eventDate"] = pd.to_datetime(felinos["eventDate"])

# Agrupación de los registros por año
felinos_registros_x_anio = felinos.groupby(felinos['eventDate'].dt.year).count().eventDate

felinos_registros_x_anio
# Out:
# eventDate
# 1839.0     6
# 1928.0     2
# 1931.0     1
# 1932.0     2
# 1933.0     1
# 1939.0     1
# 1954.0     2
# 1958.0     1
# 1963.0     2
# 1964.0     1
# 1965.0     2
# 1967.0     2
# 1970.0     1
# 1993.0     2
# 2002.0     1
# 2005.0     1
# 2007.0     1
# 2008.0     1
# 2009.0     6
# 2010.0     3
# 2011.0     2
# 2012.0     6
# 2013.0     6
# 2014.0     3
# 2015.0    10
# 2016.0     8
# 2017.0    15
# 2018.0     4
# 2019.0    20
# 2020.0    23
# 2021.0    12
# Name: eventDate, dtype: int64

# %%
# Tipo de datos retornado
type(felinos_registros_x_anio)
# Out:
# pandas.core.series.Series

# %%
# Conversión de series a dataframe
felinos_registros_x_anio_df = pd.DataFrame({'anio':felinos_registros_x_anio.index, 'registros':felinos_registros_x_anio.values}) 

# Conversión del tipo de la columna de año
felinos_registros_x_anio_df["anio"] = pd.to_numeric(felinos_registros_x_anio_df["anio"], downcast='integer')
felinos_registros_x_anio_df.style.set_precision(2)

felinos_registros_x_anio_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 6
#       4 # Conversión del tipo de la columna de año
#       5 felinos_registros_x_anio_df["anio"] = pd.to_numeric(felinos_registros_x_anio_df["anio"], downcast='integer')
# ----> 6 felinos_registros_x_anio_df.style.set_precision(2)
#       8 felinos_registros_x_anio_df
#
# AttributeError: 'Styler' object has no attribute 'set_precision'

# %%
# Graficación
felinos_registros_x_anio_df.plot(x='anio', y='registros', kind='bar', figsize=(12,7), color='red')

# Título y leyendas en los ejes
plt.title('Registros de presencia de Felidae (felinos) en Costa Rica por año', fontsize=20)
plt.xlabel('Año', fontsize=16)
plt.ylabel('Cantidad de registros', fontsize=16)
# Out:
# Text(0, 0.5, 'Cantidad de registros')

# %% [markdown]
# ##### Distribución de registros de presencia por mes

# %%
# Agrupación de los registros por mes
felinos_registros_x_mes = felinos.groupby(felinos['eventDate'].dt.month).count().eventDate

felinos_registros_x_mes
# Out:
# eventDate
# 1.0     28
# 2.0     15
# 3.0     21
# 4.0      8
# 5.0      9
# 6.0     15
# 7.0     13
# 8.0      9
# 9.0      5
# 10.0     8
# 11.0     2
# 12.0    15
# Name: eventDate, dtype: int64

# %%
# Reemplazo del número del mes por el nombre del mes
felinos_registros_x_mes.index=[calendar.month_name[x] for x in range(1,13)]

felinos_registros_x_mes
# Out:
# January      28
# February     15
# March        21
# April         8
# May           9
# June         15
# July         13
# August        9
# September     5
# October       8
# November      2
# December     15
# Name: eventDate, dtype: int64

# %%
# Gráfico de barras
felinos_registros_x_mes.plot(kind='bar',figsize=(12,7), color='blue', alpha=0.5)

# Título y leyendas en los ejes
plt.title('Registros de presencia de Felidae (felinos) en Costa Rica por mes', fontsize=20)
plt.xlabel('Mes', fontsize=16)
plt.ylabel('Cantidad de registros', fontsize=16);

# %% [markdown]
# ##### Graficación en una línea de tiempo

# %%
# Agrupación de los registros por fecha
registros_x_fecha = felinos.groupby(felinos['eventDate'].dt.date).count().eventDate

registros_x_fecha
# Out:
# eventDate
# 1839-01-01    6
# 1928-01-01    2
# 1931-05-29    1
# 1932-01-01    1
# 1932-06-01    1
#              ..
# 2021-06-03    1
# 2021-06-23    1
# 2021-07-01    1
# 2021-07-15    1
# 2021-08-11    1
# Name: eventDate, Length: 135, dtype: int64

# %%
# Gráfico de líneas
registros_x_fecha.plot(figsize=(20,8), color='blue')

# Título y leyendas en los ejes
plt.title('Registros de presencia de Felidae (felinos) en Costa Rica por fecha', fontsize=20)
plt.xlabel('Fecha',fontsize=16)
plt.ylabel('Cantidad de registros',fontsize=16);
plt.legend()
